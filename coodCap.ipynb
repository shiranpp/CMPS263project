# %%
'''
    Coordinate Capturer
    Author:Ryan Shi
    For CMPS263 project
    Capture the coodinate for all cell and minidistirct 
'''
import math
import threading
import dbbase
#Data base structure
from dbbase import session,Dist,MDist,Cell,Record,engine
import sys
import time
default_stdout = sys.stdout
default_stderr = sys.stderr
reload(sys)
sys.setdefaultencoding("utf-8")
sys.stdout = default_stdout
sys.stderr = default_stderr
import geopy
from geopy.geocoders import GoogleV3

# %%
google_api_key=['AIzaSyD6c9mPb0rTgy52TI1SLL8qYb0PHIXT0TU','AIzaSyANiLbdCbTpBe8XzrNej3i5MyVhW4YI8GY','AIzaSyAQwwaH0V5UJHUy9KtSkVIKtsEc42Wlqfw','	AIzaSyDTjJzoCh04J-fHLNadn9YoMBokLeIpA0I','AIzaSyBmhldem42uagYQGmjI9hPts6x18k3_GdU','AIzaSyD81qhHLzbaYM9oazf6ZB7WLV3o2ywuSeE']
google_api_key1=["AIzaSyA0YMY3n0eOOfiFgAqmCka3IG_DROfQQq4",'AIzaSyD81qhHLzbaYM9oazf6ZB7WLV3o2ywuSeE',"AIzaSyCrkY6CJUB-zc-hCLOXlUe0cjNTx2V2u2s"]
geolocators=[]
for key in google_api_key1:
    geolocators.append(GoogleV3(api_key=key, domain='maps.googleapis.com', scheme='https', client_id=None, secret_key=None, timeout=10, proxies=None))

# %%
class myThread (threading.Thread):   
    def __init__(self, session, cells,geolocator):
        threading.Thread.__init__(self)
        self.session = session
        self.cells = cells
        self.geolocator = geolocator
        self.n=len(self.cells)
    def run(self): 
        self.n=len(self.cells)
        self.i=0
        for cell in self.cells:
            self.i+=1;
            if (cell.cood=='' or cell.cood==None ):
                location = self.geolocator.geocode(cell.name+'  '+cell.mdist.dist.name+u' 北京')
                if location is None:
                    location = self.geolocator.geocode(cell.name+u' 北京')
                if location is not None:
                    cell.cood='['+str(location.latitude)+','+ str(location.longitude)+']'
                    print self.i,'/',self.n,'captured coodinate at'+cell.name+':'+location.address
                else:
                    cell.cood='g'
                    print self.i,'/',self.n,'no coodinate for'+cell.name

# %%
#Use the google api to capture the coodinate for all minidistirst
mdlist=session.query(MDist).all()

# %%
for md in mdlist:
    if (md.cood==''):
        location = geolocator.geocode(md.dist.name+'  '+md.name+u' 北京')
        if location is None:
            location = geolocator.geocode(md.name+u' 北京')
        if location is not None:
            md.cood='['+str(location.latitude)+','+ str(location.longitude)+']'
            print 'captured coodinate at'+md.name+':'+location.address
        else:
            print 'no coodinate for'+md.name
    session.commit()

# %%
#Use the google api to capture the coodinate for all cell
cells=session.query(Cell).filter(Cell.cood==None).all()

# %%
data=[]

# %%
n=len(cells)/3
for i in range(0,3):
    data.append(cells[i*n:min(i*n+n,len(cells))])

# %%
len(cells)
# Out:
# 2

# %%
thread1 = myThread(session, data[0], geolocators[0])
thread1.start()
thread2 = myThread(session, data[1], geolocators[1])
thread2.start()
thread3 = myThread(session, data[2], geolocators[2])
thread3.start()
thread4 = myThread(session, data[3], geolocators[3])
thread4.start()
thread5 = myThread(session, data[4], geolocators[4])
thread5.start()
# Out:
# 1 / 200 captured coodinate at和韵佳园:He Yun Jia Yuan, Haidian Qu, Beijing Shi, China, 100193
# 1 / 200 1captured coodinate at新华街二里:Xin Hua Jie Er Li 2, Fengtai Qu, Beijing Shi, China, 100070
# / 200 captured coodinate at万科紫苑:Xiaotun Rd, Fengtai Qu, Beijing Shi, China
# 2 / 200 captured coodinate at枫润家园:Feng Run Jia Yuan, Haidian Qu, Beijing Shi, China, 100193
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-bc441bba6518> in <module>()
#       5 thread3 = myThread(session, data[2], geolocators[2])
#       6 thread3.start()
# ----> 7 thread4 = myThread(session, data[3], geolocators[3])
#       8 thread4.start()
#       9 thread5 = myThread(session, data[4], geolocators[4])
#
# IndexError: list index out of range
# 2 / 200 captured coodinate at韩庄子东里:Keyi Rd, Fengtai Qu, Beijing Shi, China, 100071
# ...

# %%
thread1 = myThread(session, data[0], geolocators[0])
thread1.start()
thread2 = myThread(session, data[1], geolocators[1])
thread2.start()
thread3 = myThread(session, data[2], geolocators[2])
thread3.start()
# Out:
# 1 / 90 captured coodinate at大成时代中心:91 W 4th Ring Rd Middle, Fengtai Qu, Beijing Shi, China, 100141
# 1 / 90 captured coodinate at永顺西里:Tongzhou, Beijing, China, 101149
# 2 / 90 captured coodinate at模式口西里:China, Beijing Shi, Shijingshan Qu, 模式口西里 邮政编码: 100042
# 2 / 90 captured coodinate at京杭府:Xinhua N Rd, Tongzhou Qu, Beijing Shi, China, 101149
# 3 / 90 captured coodinate at南小园:China, Beijing, Tongzhou, Yudaihe E St, 玉带河大街26
# 4 / 90 captured coodinate at同心嘉园:China, Beijing, Tongzhou, Chezhan Rd, 车站路图书馆下车
# 5 / 90 captured coodinate at潞河中学家属院南区:135 Xinhua S Rd, Tongzhou Qu, China, 101101
# 1 / 90 captured coodinate at大营旅游度假村:Dayingcun, Tongzhou, Beijing, China
# 3 / 90 captured coodinate at西上园四区:China, Beijing, Tongzhou, Yudaihe E St, 西上园四区3
# 6 / 90 captured coodinate at旅游新村:Yudaihe E St, Tongzhou Qu, Beijing Shi, China, 101149
# 7 / 90 captured coodinate at复兴北里:Beiyuan South Rd Side Rd, Tongzhou Qu, Beijing Shi, China, 101100
# ...

# %%
thread3 = myThread(session, cells, geolocators[0])
thread3.start()
# Out:
# 1 / 2 captured coodinate at雷捷时代广场二期:China, 北京北京东燕郊国家经济技术开发区102国道电厂桥东路南
# 2 / 2 captured coodinate at上上城理想新城二期:Ding Hui Bei Qiao, Haidian Qu, Beijing Shi, China

# %%
session.commit()
